# %% [markdown]
# # Plotting Lines
# - This tutorial can be found at this [link](https://www.pygmt.org/latest/tutorials/basics/lines.html)
# - In this tutorial, we will be plotting lines

# %%
import pygmt

# %%
# Plotting a single line segment
fig = pygmt.Figure()
fig.plot(
  region = [0, 10, 0, 10],
  projection = "X15c/10c",
  frame = "a", x = [1, 8], y = [5, 9], pen = "1p,black"
)
fig.show()

# %%
# Plotting Multiple line segments
fig = pygmt.Figure()
fig.plot(
  region = [0, 10, 0, 10],
  projection = "X15c/10c",
  frame = "a", 
  x = [1, 6, 9], y = [5, 7, 4], 
  pen = "1p,black"
)
fig.show()

# %%
# Plotting multiple lines
fig = pygmt.Figure()
fig.plot(
  region = [0, 10, 0, 10],
  projection = "X15c/10c",
  frame = "a", 
  x = [1, 6, 9], y = [5, 7, 4], 
  pen = "2p,blue"
)
fig.plot(x=[2, 4, 10], y=[3, 8, 9], pen="2p,red")
fig.show()

# %%
# Changing line attributes
fig = pygmt.Figure()
fig.plot(
    region=[0, 10, 0, 10],
    projection="X15c/10c",
    frame="a",
    x=[1, 8],
    y=[3, 9],
    pen="5p",
)
fig.show()

# %%
fig = pygmt.Figure()
fig.plot(
    region=[0, 10, 0, 10],
    projection="X15c/10c",
    frame="a",
    x=[1, 8],
    y=[3, 9],
    pen="5p,red",
)
fig.show()

# %%
fig = pygmt.Figure()
fig.plot(
    region=[0, 10, 0, 10],
    projection="X15c/10c",
    frame="a",
    x=[1, 8],
    y=[3, 9],
    pen="5p,..-",
)
fig.show()

# %%
fig = pygmt.Figure()
fig.plot(
    region=[0, 10, 0, 10],
    projection="X15c/10c",
    frame="a",
    x=[1, 8],
    y=[3, 9],
    pen="7p,green,-.-",
)
fig.show()
