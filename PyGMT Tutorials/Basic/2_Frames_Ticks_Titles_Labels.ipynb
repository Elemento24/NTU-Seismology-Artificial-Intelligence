# %% [markdown]
# # Frames, Ticks, Titles and Labels
# - This tutorial can be found at this [link](https://www.pygmt.org/latest/tutorials/basics/frames.html)
# - In this tutorial, we will be setting the style of the map frames, ticks, etc.

# %%
import pygmt

# %%
# Plotting a frame
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[-180, 180, -60, 60], projection="M25c")
fig.show()

# %%
# Adding the default GMT frame, "f"
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[-180, 180, -60, 60], projection="M25c")
fig.basemap(frame="f")
fig.show()

# %%
# Adding ticks and grid lines
# The automatic frame (True or "a") sets the default GMT style frame, and determines the tick
# labels automatically
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[-180, 180, -60, 60], projection="M25c")
fig.basemap(frame="a")
fig.show()

# %%
# Adding automatic grid lines to the plot, "g"
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region=[-180, 180, -60, 60], projection="M25c")
fig.basemap(frame="ag")
fig.show()

# %%
# Adding the title
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region="IS", projection="M25c")
fig.basemap(frame=["a", "+tIceland"])
fig.show()

# %%
# Title with Multiple words
fig = pygmt.Figure()
fig.coast(shorelines="1/0.5p", region="TT", projection="M25c")
fig.basemap(frame=["a", '+t"Trinidad and Tobago"'])
fig.show()

# %%
# Adding axis labels
# If an upper-case axis name is passed, the axis is plotted with tick marks and axis labels. 
# A lower case axis name plots only the axis and tick marks.
fig = pygmt.Figure()
fig.basemap(
  region = [0, 10, 0, 20],
  projection = "X10c/8c",
  frame=["WSne", "xaf+lx-axis", "yaf+ly-axis"]
)
fig.show()
