# %%
import os
import glob
import obspy
import numpy as np
from obspy.signal.trigger import classic_sta_lta
from obspy.taup import TauPyModel
from matplotlib import pyplot as plt, patches

# %%
provider = "IRIS" 
year = 2018
evt_check = "20181128101709090000"
data_sac = f'/home/elemento/Music/Auto_PickP/Use/Download/{provider}/SAC/{year}'
data_dir = f'{data_sac}/{evt_check}'
os.listdir(data_dir)
# Out:
# ['AV.PLK1..BHZ.SAC',
#  'CH.LIENZ..BHZ.SAC',
#  'AK.GRNC..BHZ.SAC.bp',
#  'AK.BERG..BHZ.SAC.bp',
#  'AV.GSTR..EHZ.SAC',
#  'IU.KIEV.00.BHZ.SAC',
#  'HT.FNA..HHZ.SAC.bp',
#  '1E.MONT4..HHZ.SAC.bp',
#  'AU.MUN..BHZ.SAC',
#  'DK.SOEG.00.BHZ.SAC.bp',
#  'IU.JOHN.00.BHZ.SAC',
#  'AK.PWL..BHZ.SAC.bp',
#  'AU.NFK..BHZ.SAC',
#  'JP.JMN..BHZ.SAC',
#  'CN.BVCY..HHZ.SAC',
#  'IM.IL31..BHZ.SAC',
#  'BE.RCHB..BHZ.SAC.bp',
#  'CA.CORG..HHZ.SAC',
#  'CN.MOBC..HHZ.SAC.bp',
#  'AV.RED..BHZ.SAC.bp',
#  'II.ABPO.00.BHZ.SAC.bp',
#  'AK.GRNC..BHZ.SAC',
#  'II.AAK.00.BHZ.SAC.bp',
#  'C8.BUTB..HHZ.SAC',
#  'AV.ILS..BHZ.SAC.bp',
#  'DK.BSD..BHZ.SAC.bp',
#  'AK.WAX..BHZ.SAC',
#  'II.SUR.00.BHZ.SAC',
#  'AK.RND..BHZ.SAC.bp',
#  'CH.FIESA..BHZ.SAC',
#  'CN.HYT..HHZ.SAC',
#  'AK.TRF..BHZ.SAC',
#  'AU.BLDU..BHZ.SAC',
#  'AK.LOGN..BHZ.SAC.bp',
#  'DE.UAF02..HHZ.SAC.bp',
#  'AK.WRH..BHZ.SAC.bp',
#  'AT.MID..BHZ.SAC.bp',
#  'JP.JEW..BHZ.SAC.bp',
#  'CN.YUK4..HHZ.SAC',
#  '8A.AROB..BHZ.SAC',
#  'AV.VNHG..EHZ.SAC',
#  'AV.GASW..EHZ.SAC',
#  'G.TAM.00.BHZ.SAC',
#  'IU.PAB.00.BHZ.SAC.bp',
#  'CN.NDB..HHZ.SAC',
#  'II.ARTI.00.BHZ.SAC.bp',
#  'JP.JMM..BHZ.SAC.bp',
#  'AV.KOFP..EHZ.SAC.bp',
#  'CA.CMAS..HHZ.SAC',
#  'IU.PET.00.BHZ.SAC',
#  'AV.WEBT..BHZ.SAC',
#  '8A.BAHE..BHZ.SAC',
#  'DK.ICESG.00.BHZ.SAC',
#  'KO.GAZ..BHZ.SAC.bp',
#  '8A.HOCH..BHZ.SAC',
#  '7C.MM27..BHZ.SAC.bp',
#  'AV.PLBL..BHZ.SAC',
#  'GE.SUMG..BHZ.SAC.bp',
#  'IU.KBL..BHZ.SAC.bp',
#  'DE.UAF02..HHZ.SAC',
#  'AU.BLDU..BHZ.SAC.bp',
#  'CN.YUK3..HHZ.SAC.bp',
#  'C8.GRIB..HHZ.SAC.bp',
#  'G.CRZF.00.BHZ.SAC.bp',
#  'AK.RDOG..BHZ.SAC',
#  'AV.ISNN..EHZ.SAC',
#  'AV.WESN..EHZ.SAC',
#  'II.KURK.00.BHZ.SAC',
#  'JP.JMZ..BHZ.SAC',
#  'IU.ADK.00.BHZ.SAC',
#  'AU.PSAD1.00.BHZ.SAC',
#  'IU.KBS.00.BHZ.SAC.bp',
#  'CH.FUORN..BHZ.SAC',
#  'CA.CBEU..HHZ.SAC',
#  'CA.CEST..HHZ.SAC',
#  'AU.CMSA..BHZ.SAC.bp',
#  'AK.WAT6..BHZ.SAC.bp',
#  'II.RAYN.00.BHZ.SAC',
#  'AU.YAPP.00.BHZ.SAC.bp',
#  'CA.ARBS..HHZ.SAC.bp',
#  'IM.IL31..BHZ.SAC.bp',
#  'IU.FUNA.00.BHZ.SAC',
#  'AT.SVW2..BHZ.SAC.bp',
#  'CN.YUK8..HHZ.SAC.bp',
#  'CN.KUKN..HHZ.SAC.bp',
#  'GT.LBTB.00.BHZ.SAC.bp',
#  'AU.MILA.00.BHZ.SAC',
#  'AK.SPIA..BHZ.SAC.bp',
#  'AK.KHIT..BHZ.SAC.bp',
#  'IU.KEV.00.BHZ.SAC',
#  'AK.SAMH..BHZ.SAC.bp',
#  'AK.DOT..BHZ.SAC',
#  'AK.ISLE..BHZ.SAC.bp',
#  'AK.RC01..BHZ.SAC.bp',
#  'AK.PIN..BHZ.SAC.bp',
#  'AU.KDU..BHZ.SAC',
#  'AC.LSK..HHZ.SAC.bp',
#  'AK.BPAW..BHZ.SAC.bp',
#  'AU.RABL.00.BHZ.SAC.bp',
#  'AV.TASE..EHZ.SAC',
#  'AK.CAST..BHZ.SAC',
#  'IU.PAB.00.BHZ.SAC',
#  'AU.OOD..BHZ.SAC.bp',
#  'II.SIMI.00.BHZ.SAC.bp',
#  'AK.DIV..BHZ.SAC.bp',
#  'AK.HOM..BHZ.SAC.bp',
#  'AV.KOWE..EHZ.SAC',
#  'EI.IDGL..BHZ.SAC',
#  'AV.MCIR..BHZ.SAC.bp',
#  '7C.MM22..BHZ.SAC.bp',
#  'II.OBN.00.BHZ.SAC.bp',
#  'AV.VNSG..EHZ.SAC',
#  'JP.JTU..BHZ.SAC',
#  'CA.CLLI..HHZ.SAC.bp',
#  'IU.PET.00.BHZ.SAC.bp',
#  'IU.COLA.00.BHZ.SAC.bp',
#  'G.IVI.00.BHZ.SAC.bp',
#  'CN.ILON..HHZ.SAC',
#  'AK.GLI..BHZ.SAC',
#  'IU.TARA.00.BHZ.SAC',
#  'GT.BOSA.00.BHZ.SAC',
#  'AK.WRH..BHZ.SAC',
#  'AK.EYAK..BHZ.SAC',
#  'AU.PSAD1.00.BHZ.SAC.bp',
#  'AU.MANU.00.BHZ.SAC',
#  'IU.FUNA.00.BHZ.SAC.bp',
#  'GT.LBTB.00.BHZ.SAC',
#  'AV.ANCK..BHZ.SAC',
#  'II.KAPI.00.BHZ.SAC.bp',
#  'II.ABPO.00.BHZ.SAC',
#  'AT.OHAK..BHZ.SAC',
#  'AV.RDT..BHZ.SAC.bp',
#  'AK.CHN..BHZ.SAC',
#  'CA.CARA..HHZ.SAC.bp',
#  '7C.MM27..BHZ.SAC',
#  'AV.ETKA..EHZ.SAC.bp',
#  'IU.YSS.00.BHZ.SAC',
#  'AV.OKWE..EHZ.SAC',
#  'AV.KIWB..EHZ.SAC',
#  'AU.WR9..BHZ.SAC.bp',
#  'AK.ANM..BHZ.SAC',
#  'AU.WRKA..BHZ.SAC',
#  'KO.GAZ..BHZ.SAC',
#  'JP.JEM..BHZ.SAC',
#  'CZ.KHC..BHZ.SAC.bp',
#  'AV.OKAK..EHZ.SAC',
#  'CA.EBR..HHZ.SAC',
#  'CN.PCLB..HHZ.SAC.bp',
#  'AU.OOD..BHZ.SAC',
#  'BE.MEM..HHZ.SAC.bp',
#  'AK.PPLA..BHZ.SAC.bp',
#  'AK.SCRK..BHZ.SAC',
#  'AV.ANNW..EHZ.SAC.bp',
#  'AV.MREP..EHZ.SAC',
#  'AV.GSCK..EHZ.SAC',
#  'II.KIV.00.BHZ.SAC',
#  'AU.MTN..BHZ.SAC.bp',
#  'G.FOMA.00.BHZ.SAC',
#  'G.DZM.00.BHZ.SAC',
#  'AK.TGL..BHZ.SAC',
#  'II.COCO.00.BHZ.SAC',
#  'II.KDAK.00.BHZ.SAC',
#  'AT.CHGN..BHZ.SAC.bp',
#  'IU.DAV.00.BHZ.SAC.bp',
#  'AK.GLB..BHZ.SAC',
#  'AK.PAX..BHZ.SAC',
#  '8A.MALT..BHZ.SAC',
#  'AV.ANPK..EHZ.SAC',
#  '1E.MONT2..HHZ.SAC',
#  'AK.SAMH..BHZ.SAC',
#  'EI.IWEX..BHZ.SAC.bp',
#  'AV.KJL..BHZ.SAC',
#  'AU.KNRA.00.BHZ.SAC',
#  'DK.ISOG..BHZ.SAC',
#  '8A.WAND..BHZ.SAC',
#  'DK.TULEG..BHZ.SAC',
#  'JP.JOW..BHZ.SAC',
#  'JP.JHJ2..BHZ.SAC',
#  'AT.TTA..BHZ.SAC.bp',
#  'II.BORG.00.BHZ.SAC.bp',
#  'DK.NRS..BHZ.SAC',
#  'AK.HOM..BHZ.SAC',
#  'JP.JGF..BHZ.SAC',
#  'CN.BMTB..HHZ.SAC.bp',
#  'II.LVZ.00.BHZ.SAC',
#  'AV.WEBT..BHZ.SAC.bp',
#  'AU.FORT..BHZ.SAC',
#  'AK.CHUM..BHZ.SAC',
#  'AK.GCSA..BHZ.SAC.bp',
#  'II.SIMI.00.BHZ.SAC',
#  'AK.KAI..BHZ.SAC.bp',
#  'AV.GSIG..EHZ.SAC',
#  'AK.VRDI..BHZ.SAC.bp',
#  'IU.BILL.00.BHZ.SAC',
#  'AK.GHO..BHZ.SAC.bp',
#  'AK.ATKA..BHZ.SAC',
#  'AU.ARMA..BHZ.SAC',
#  'GO.BATM..HHZ.SAC',
#  'II.KURK.00.BHZ.SAC.bp',
#  'AV.OKER..EHZ.SAC.bp',
#  'AK.BMR..BHZ.SAC.bp',
#  'AK.KTH..BHZ.SAC',
#  'AK.CRQ..BHZ.SAC.bp',
#  'IC.HIA.00.BHZ.SAC.bp',
#  'IU.GUMO.00.BHZ.SAC',
#  'CH.MUGIO..BHZ.SAC.bp',
#  'AV.TANO..EHZ.SAC',
#  'AK.GAMB..BHZ.SAC',
#  'AK.KHIT..BHZ.SAC',
#  'DK.MUD..BHZ.SAC',
#  'CN.HYT..HHZ.SAC.bp',
#  'AK.RDOG..BHZ.SAC.bp',
#  'HL.KEK..HHZ.SAC',
#  'AK.ATKA..BHZ.SAC.bp',
#  'IU.YAK.00.BHZ.SAC',
#  'AV.PN7A..BHZ.SAC.bp',
#  'AV.RED..BHZ.SAC',
#  'AV.KARR..EHZ.SAC',
#  'CN.DLBC..BHZ.SAC',
#  'EI.IWEX..BHZ.SAC',
#  'AV.WAZA..BHZ.SAC',
#  'II.KAPI.00.BHZ.SAC',
#  'AV.PS1A..BHZ.SAC',
#  'AV.ILS..BHZ.SAC',
#  'KO.ELL..BHZ.SAC',
#  'CN.DAWY..HHZ.SAC',
#  '7C.MM22..BHZ.SAC',
#  'BE.UCC..HHZ.SAC',
#  'II.BRVK.00.BHZ.SAC',
#  'JP.JYT..BHZ.SAC',
#  'AV.ANCK..BHZ.SAC.bp',
#  'CN.FNSB..HHZ.SAC.bp',
#  'G.SSB.00.BHZ.SAC.bp',
#  'GE.VSU..BHZ.SAC.bp',
#  '8A.ARON..BHZ.SAC.bp',
#  'IU.INCN.00.BHZ.SAC',
#  'HL.ITM..HHZ.SAC',
#  'AT.CRAG..BHZ.SAC',
#  'AK.LOGN..BHZ.SAC',
#  'G.DZM.00.BHZ.SAC.bp',
#  'AV.VNNF..EHZ.SAC',
#  'IU.YSS.00.BHZ.SAC.bp',
#  'AV.WTUG..EHZ.SAC',
#  'AV.PLK1..BHZ.SAC.bp',
#  'AV.PS4A..BHZ.SAC',
#  'CN.YUK5..HHZ.SAC',
#  'HL.ARG..HHZ.SAC',
#  'CN.DIB..HHZ.SAC.bp',
#  'CN.INK..BHZ.SAC.bp',
#  'AV.OKSP..EHZ.SAC.bp',
#  'AK.SAW..BHZ.SAC.bp',
#  'AT.PMR..BHZ.SAC.bp',
#  'AV.RDT..BHZ.SAC',
#  'AV.MAPS..BHZ.SAC.bp',
#  'JP.JEW..BHZ.SAC',
#  'DK.ANGG..BHZ.SAC',
#  'IU.MA2.00.BHZ.SAC.bp',
#  'II.TAU.00.BHZ.SAC.bp',
#  'AU.PSAD2.00.BHZ.SAC',
#  '1E.MONT6..HHZ.SAC.bp',
#  'AK.BWN..BHZ.SAC',
#  'AK.MCAR..BHZ.SAC',
#  'AV.KCG..EHZ.SAC.bp',
#  'BX.CKGRV..BHZ.SAC',
#  'IU.NWAO.00.BHZ.SAC',
#  'AK.COLD..BHZ.SAC',
#  'CN.YUK2..HHZ.SAC.bp',
#  'AU.FITZ..BHZ.SAC.bp',
#  'AK.GRIN..BHZ.SAC.bp',
#  'AU.WR2..BHZ.SAC.bp',
#  'G.FOMA.00.BHZ.SAC.bp',
#  'AV.OKWE..EHZ.SAC.bp',
#  'AK.GCSA..BHZ.SAC',
#  'AK.COLD..BHZ.SAC.bp',
#  'AU.MORW..BHZ.SAC',
#  'AV.SPBL..BHZ.SAC',
#  'AV.KJL..BHZ.SAC.bp',
#  'CN.YUK8..HHZ.SAC',
#  'AK.SAW..BHZ.SAC',
#  'AV.ZRO..BHZ.SAC',
#  'AK.BAL..BHZ.SAC',
#  'AF.POGA..BHZ.SAC',
#  'AK.FID..BHZ.SAC.bp',
#  'KG.TJN..BHZ.SAC',
#  'DK.NUUG.00.BHZ.SAC.bp',
#  'AK.RIDG..BHZ.SAC',
#  'AK.SCM..BHZ.SAC',
#  'CN.DIB..HHZ.SAC',
#  'AC.PUK..HHZ.SAC.bp',
#  'CA.CCAS..HHZ.SAC.bp',
#  'AK.RC01..BHZ.SAC',
#  'AK.BPAW..BHZ.SAC',
#  'AK.PWL..BHZ.SAC',
#  'G.ROCAM.00.BHZ.SAC',
#  'AK.CYK..BHZ.SAC',
#  '1E.MONT7..HHZ.SAC',
#  'AV.KIWB..EHZ.SAC.bp',
#  'AK.MCK..BHZ.SAC',
#  'AK.CRQ..BHZ.SAC',
#  'CN.YUK5..HHZ.SAC.bp',
#  'AU.KELC.00.BHZ.SAC.bp',
#  'KO.KARS..HHZ.SAC',
#  'CN.YUK7..HHZ.SAC.bp',
#  'IU.CASY.00.BHZ.SAC.bp',
#  'IU.PMG.00.BHZ.SAC',
#  'AK.MLY..BHZ.SAC.bp',
#  'G.IVI.00.BHZ.SAC',
#  'AU.BBOO..BHZ.SAC',
#  'AV.KOFP..EHZ.SAC',
#  'II.DGAR.00.BHZ.SAC.bp',
#  'AK.SWD..BHZ.SAC',
#  'CZ.DPC..BHZ.SAC.bp',
#  'CA.CTRE..HHZ.SAC.bp',
#  'AU.MAW..BHZ.SAC.bp',
#  '8A.GAMM..BHZ.SAC',
#  '1E.MONT4..HHZ.SAC',
#  'AU.MULG..BHZ.SAC.bp',
#  'CN.BRWY..HHZ.SAC.bp',
#  'AU.KELC.00.BHZ.SAC',
#  'G.FUTU.00.BHZ.SAC.bp',
#  '1E.MONT1..HHZ.SAC',
#  'EI.VAL..BHZ.SAC',
#  'HT.ALN..HHZ.SAC.bp',
#  'AV.PLK5..BHZ.SAC',
#  'AK.DHY..BHZ.SAC',
#  'AV.TANO..EHZ.SAC.bp',
#  'C8.MBLB..HHZ.SAC',
#  'DK.NUUG.00.BHZ.SAC',
#  'IU.TIXI.00.BHZ.SAC.bp',
#  'AK.TABL..BHZ.SAC',
#  'AF.POGA..BHZ.SAC.bp',
#  'CN.KUKN..HHZ.SAC',
#  'CA.CAVN..HHZ.SAC',
#  'II.BRVK.00.BHZ.SAC.bp',
#  'AV.AKSA..BHZ.SAC',
#  'AT.SVW2..BHZ.SAC',
#  'G.RER.00.BHZ.SAC',
#  'CH.BRANT..BHZ.SAC',
#  'IU.TIXI.00.BHZ.SAC',
#  'AK.BERG..BHZ.SAC',
#  'AU.QIS..BHZ.SAC.bp',
#  'AU.LHI.00.BHZ.SAC',
#  'IC.HIA.00.BHZ.SAC',
#  'JP.JOW..BHZ.SAC.bp',
#  'AK.WAX..BHZ.SAC.bp',
#  'AU.INKA..BHZ.SAC',
#  'AK.WAT6..BHZ.SAC',
#  'AK.DIV..BHZ.SAC',
#  'IU.MBWA.00.BHZ.SAC.bp',
#  'AK.CTG..BHZ.SAC.bp',
#  'AU.AS31..BHZ.SAC.bp',
#  'AK.CAPN..BHZ.SAC',
#  'KO.BZK..BHZ.SAC.bp',
#  'IU.MIDW.00.BHZ.SAC.bp',
#  'G.PAF.00.BHZ.SAC.bp',
#  'II.KDAK.00.BHZ.SAC.bp',
#  'AV.PLK3..BHZ.SAC',
#  'AK.SKN..BHZ.SAC',
#  'AK.NIKH..BHZ.SAC',
#  'AU.KDU..BHZ.SAC.bp',
#  'AU.SDAN.00.BHZ.SAC',
#  'AV.VNKR..EHZ.SAC',
#  'AV.BOGO..BHZ.SAC.bp',
#  'AK.TNA..BHZ.SAC.bp',
#  'AV.SPCP..BHZ.SAC.bp',
#  'AK.WAT7..BHZ.SAC.bp',
#  'AV.ETKA..EHZ.SAC',
#  'AU.CNB..BHZ.SAC.bp',
#  'AV.AUWS..BHZ.SAC.bp',
#  'C8.MBLB..HHZ.SAC.bp',
#  'AV.KIMD..EHZ.SAC',
#  'AK.GLB..BHZ.SAC.bp',
#  'JP.JSD..BHZ.SAC.bp',
#  'AU.TOO.00.BHZ.SAC.bp',
#  '8A.ARON..BHZ.SAC',
#  'AK.TNA..BHZ.SAC',
#  'AU.MEEK..BHZ.SAC.bp',
#  'CN.PLBC..HHZ.SAC.bp',
#  'G.ROCAM.00.BHZ.SAC.bp',
#  'II.MSVF.00.BHZ.SAC',
#  '8A.HELM..BHZ.SAC.bp',
#  'AK.CHI..BHZ.SAC',
#  'AU.QIS..BHZ.SAC',
#  'AU.AS31..BHZ.SAC',
#  'snr.info',
#  'AK.SSP..BHZ.SAC',
#  '8A.WAND..BHZ.SAC.bp',
#  'AK.WAT1..HHZ.SAC.bp',
#  'CN.FNSB..HHZ.SAC',
#  'AU.MILA.00.BHZ.SAC.bp',
#  'AV.GSTR..EHZ.SAC.bp',
#  'AK.HIN..BHZ.SAC',
#  'DK.DBG.00.BHZ.SAC',
#  'AK.CCB..BHZ.SAC.bp',
#  'AK.SCM..BHZ.SAC.bp',
#  'DK.NOR..BHZ.SAC',
#  'KO.BNN..BHZ.SAC.bp',
#  'AV.TAPA..EHZ.SAC',
#  'IU.COLA.00.BHZ.SAC',
#  'BE.RCHB..BHZ.SAC',
#  'AU.WB6..BHZ.SAC.bp',
#  'AK.EYAK..BHZ.SAC.bp',
#  'IU.FURI.00.BHZ.SAC',
#  'AU.FITZ..BHZ.SAC',
#  '8A.AIAI..BHZ.SAC',
#  'CN.FRB..BHZ.SAC',
#  'CN.RUBB..HHZ.SAC',
#  'EI.DSB..BHZ.SAC',
#  'AK.FALS..BHZ.SAC',
#  'HL.RDO..HHZ.SAC.bp',
#  'AU.STKA..BHZ.SAC.bp',
#  'CA.CORI..HHZ.SAC.bp',
#  'AV.OKID..EHZ.SAC',
#  'CZ.KHC..BHZ.SAC',
#  'AV.KVT..EHZ.SAC',
#  'JP.JSU..BHZ.SAC',
#  'AU.WB10..BHZ.SAC.bp',
#  'AV.PLBL..BHZ.SAC.bp',
#  'AK.SSP..BHZ.SAC.bp',
#  'AV.SPBL..BHZ.SAC.bp',
#  'IU.YAK.00.BHZ.SAC.bp',
#  'AK.MLY..BHZ.SAC',
#  'AK.PPD..BHZ.SAC',
#  'DK.NEEM.10.BHZ.SAC.bp',
#  'IM.MK31..BHZ.SAC',
#  'CN.YUK3..HHZ.SAC',
#  'II.DGAR.00.BHZ.SAC',
#  'CZ.DPC..BHZ.SAC',
#  'AK.GOAT..BHZ.SAC.bp',
#  'AV.SPCP..BHZ.SAC',
#  'AK.CAPN..BHZ.SAC.bp',
#  'AT.SDPT..BHZ.SAC.bp',
#  'IU.MAJO.00.BHZ.SAC',
#  'AK.PPLA..BHZ.SAC',
#  'CA.EBR..HHZ.SAC.bp',
#  'IU.KEV.00.BHZ.SAC.bp',
#  'CN.BLKN..HHZ.SAC',
#  'CN.INK..BHZ.SAC',
#  'AK.FYU..BHZ.SAC',
#  'AU.MEEK..BHZ.SAC',
#  'AU.PSAB2.00.BHZ.SAC',
#  'EI.IDGL..BHZ.SAC.bp',
#  'AK.HDA..BHZ.SAC.bp',
#  'AK.VRDI..BHZ.SAC',
#  'IU.NWAO.00.BHZ.SAC.bp',
#  'AK.BESE..BHZ.SAC',
#  'AV.KAWH..EHZ.SAC',
#  'AK.HDA..BHZ.SAC',
#  'AU.MANU.00.BHZ.SAC.bp',
#  'JP.JGF..BHZ.SAC.bp',
#  'II.KIV.00.BHZ.SAC.bp',
#  'AV.KEL..EHZ.SAC.bp',
#  'AK.KAI..BHZ.SAC',
#  'IU.GNI.00.BHZ.SAC.bp',
#  'AU.FORT..BHZ.SAC.bp',
#  'JP.JSD..BHZ.SAC',
#  'IU.BILL.00.BHZ.SAC.bp',
#  'CA.CAVN..HHZ.SAC.bp',
#  'AK.HIN..BHZ.SAC.bp',
#  'II.COCO.00.BHZ.SAC.bp',
#  'CA.CORI..HHZ.SAC',
#  'HL.RDO..HHZ.SAC',
#  'IU.ANTO.00.BHZ.SAC',
#  'AU.QLP..BHZ.SAC.bp',
#  '8A.MARI..BHZ.SAC',
#  'AU.CNB..BHZ.SAC',
#  'IU.ANTO.00.BHZ.SAC.bp',
#  'G.ATD.00.BHZ.SAC',
#  'AU.BBOO..BHZ.SAC.bp',
#  'KG.TJN..BHZ.SAC.bp',
#  'CA.CSOR..HHZ.SAC',
#  'CH.LIENZ..BHZ.SAC.bp',
#  'CN.DAWY..HHZ.SAC.bp',
#  'AK.DOT..BHZ.SAC.bp',
#  'BE.MEM..HHZ.SAC',
#  'IU.MA2.00.BHZ.SAC',
#  'AU.YNG..BHZ.SAC',
#  'AK.CAST..BHZ.SAC.bp',
#  'AK.PIN..BHZ.SAC',
#  'DK.NEEM.10.BHZ.SAC',
#  'AV.ISNN..EHZ.SAC.bp',
#  'JP.JTM..BHZ.SAC.bp',
#  'AV.ISLZ..BHZ.SAC.bp',
#  'CN.FSJB..HHZ.SAC',
#  'IU.FURI.00.BHZ.SAC.bp',
#  'G.ATD.00.BHZ.SAC.bp',
#  'AU.LCRK..BHZ.SAC',
#  'JP.JTM..BHZ.SAC',
#  'IU.HNR.00.BHZ.SAC.bp',
#  'IU.ULN.00.BHZ.SAC',
#  'AV.KABR..EHZ.SAC',
#  'AK.JIS..BHZ.SAC',
#  'JP.JMN..BHZ.SAC.bp',
#  'CA.CLLI..HHZ.SAC',
#  'AU.MUN..BHZ.SAC.bp',
#  'AU.GIRL..BHZ.SAC',
#  'AF.TEBE..BHZ.SAC',
#  'AK.TGL..BHZ.SAC.bp',
#  'C8.GRNB..HHZ.SAC',
#  'AV.AUWS..BHZ.SAC',
#  'II.BORG.00.BHZ.SAC',
#  'CA.CORG..HHZ.SAC.bp',
#  'CN.YKAW3..BHZ.SAC.bp',
#  'AV.BOGO..BHZ.SAC',
#  'AT.MID..BHZ.SAC',
#  'CN.YUK7..HHZ.SAC',
#  'IU.LSZ.00.BHZ.SAC',
#  'JP.JKA..BHZ.SAC',
#  '8A.OKAM..BHZ.SAC',
#  'CH.FIESA..BHZ.SAC.bp',
#  'CN.YKAW1..BHZ.SAC',
#  'CA.CPAL..HHZ.SAC',
#  'CA.CARA..HHZ.SAC',
#  'JP.JMM..BHZ.SAC',
#  'AK.KLU..BHZ.SAC',
#  'DK.NUUK.00.BHZ.SAC',
#  'GE.UGM..BHZ.SAC',
#  'II.TAU.00.BHZ.SAC',
#  '1E.MONT5..HHZ.SAC.bp',
#  'IU.MAJO.00.BHZ.SAC.bp',
#  'AK.KNK..BHZ.SAC.bp',
#  'CN.BNAB..HHZ.SAC',
#  'AV.CLCO..BHZ.SAC',
#  'G.FUTU.00.BHZ.SAC',
#  'AU.HTT..BHZ.SAC.bp',
#  'AV.AKGG..BHZ.SAC',
#  'AU.WB6..BHZ.SAC',
#  'IU.GUMO.00.BHZ.SAC.bp',
#  'G.CAN.00.BHZ.SAC.bp',
#  '1E.MONT7..HHZ.SAC.bp',
#  'GT.BOSA.00.BHZ.SAC.bp',
#  'AU.TOO.00.BHZ.SAC',
#  '8A.AROB..BHZ.SAC.bp',
#  'II.ARTI.00.BHZ.SAC',
#  'AK.BWN..BHZ.SAC.bp',
#  'AK.WAT7..BHZ.SAC',
#  'AV.ANPB..EHZ.SAC.bp',
#  'IU.KIP.00.BHZ.SAC',
#  'CA.ARBS..HHZ.SAC',
#  'AU.MAW..BHZ.SAC',
#  'CA.CBRU..HHZ.SAC',
#  'II.UOSS.00.BHZ.SAC.bp',
#  'AK.SLK..BHZ.SAC',
#  'GE.EIL..BHZ.SAC',
#  'AK.GOAT..BHZ.SAC',
#  'C8.HWKB..HHZ.SAC',
#  'AU.PSAD3.00.BHZ.SAC',
#  'G.CAN.00.BHZ.SAC',
#  'AU.MTN..BHZ.SAC',
#  'AF.SKRH..BHZ.SAC',
#  'AT.CRAG..BHZ.SAC.bp',
#  'AU.RIV..BHZ.SAC',
#  'CN.POIN..HHZ.SAC.bp',
#  'AV.OKSP..EHZ.SAC',
#  'AK.SCRK..BHZ.SAC.bp',
#  'AK.BCP..BHZ.SAC.bp',
#  'GE.TIRR..BHZ.SAC.bp',
#  'IU.SFJD.00.BHZ.SAC',
#  'IU.KBS.00.BHZ.SAC',
#  'AU.INKA..BHZ.SAC.bp',
#  'AK.CHI..BHZ.SAC.bp',
#  'AK.BARK..BHZ.SAC.bp',
#  'DK.SCO..BHZ.SAC',
#  'AU.LCRK..BHZ.SAC.bp',
#  'G.CLF.00.BHZ.SAC.bp',
#  'HT.FNA..HHZ.SAC',
#  'C8.HWKB..HHZ.SAC.bp',
#  'AU.CMSA..BHZ.SAC',
#  'EI.IGLA..BHZ.SAC',
#  'AV.KEL..EHZ.SAC',
#  'AU.YAPP.00.BHZ.SAC',
#  'AK.UNV..BHZ.SAC',
#  'HL.KEK..HHZ.SAC.bp',
#  'G.RER.00.BHZ.SAC.bp',
#  'EI.VAL..BHZ.SAC.bp',
#  'JP.JSG..BHZ.SAC',
#  'CN.YUK2..HHZ.SAC',
#  'AU.ARMA..BHZ.SAC.bp',
#  'AV.KAPH..EHZ.SAC',
#  'AK.PNL..BHZ.SAC',
#  'AV.ILW..EHZ.SAC',
#  '8A.KANO..BHZ.SAC',
#  'AV.OKID..EHZ.SAC.bp',
#  'IU.MAKZ.00.BHZ.SAC.bp',
#  'AU.EIDS..BHZ.SAC.bp',
#  'GO.BATM..HHZ.SAC.bp',
#  'KO.GURO..HHZ.SAC',
#  'IU.KONO.00.BHZ.SAC',
#  'AU.WR9..BHZ.SAC',
#  'AK.PTPK..BHZ.SAC.bp',
#  'AT.TTA..BHZ.SAC',
#  'AT.SKAG..BHZ.SAC',
#  'IU.PMG.00.BHZ.SAC.bp',
#  'CN.PCLB..HHZ.SAC',
#  '1E.MONT3..HHZ.SAC',
#  'IU.DAV.00.BHZ.SAC',
#  'IU.GRFO..BHZ.SAC.bp',
#  'AK.CTG..BHZ.SAC',
#  'CN.PLBC..HHZ.SAC',
#  'CN.RUBB..HHZ.SAC.bp',
#  'G.PAF.00.BHZ.SAC',
#  'AV.SSLW..EHZ.SAC',
#  'AV.VNWF..EHZ.SAC',
#  'AK.MCK..BHZ.SAC.bp',
#  'AV.SSLS..BHZ.SAC',
#  'AU.COEN..BHZ.SAC.bp',
#  'AU.YNG..BHZ.SAC.bp',
#  'AT.SKAG..BHZ.SAC.bp',
#  'AU.QLP..BHZ.SAC',
#  'IU.MBWA.00.BHZ.SAC',
#  'II.UOSS.00.BHZ.SAC',
#  'AK.RND..BHZ.SAC',
#  'AU.KMBL..BHZ.SAC.bp',
#  'AU.WB10..BHZ.SAC',
#  'IU.JOHN.00.BHZ.SAC.bp',
#  'AU.PSAB2.00.BHZ.SAC.bp',
#  'AK.KIAG..BHZ.SAC.bp',
#  'AK.GHO..BHZ.SAC',
#  'AU.LHI.00.BHZ.SAC.bp',
#  '8A.AIAI..BHZ.SAC.bp',
#  'CA.CEST..HHZ.SAC.bp',
#  'AU.COEN..BHZ.SAC',
#  'AV.STLK..BHZ.SAC',
#  'AU.PSAD3.00.BHZ.SAC.bp',
#  'AK.CHUM..BHZ.SAC.bp',
#  'AV.TAPA..EHZ.SAC.bp',
#  'AT.YKU2..BHZ.SAC',
#  'AU.MULG..BHZ.SAC',
#  'CA.CBRU..HHZ.SAC.bp',
#  'G.TAM.00.BHZ.SAC.bp',
#  'AK.BAL..BHZ.SAC.bp',
#  'AV.TASE..EHZ.SAC.bp',
#  'AV.KAHC..EHZ.SAC',
#  'G.AIS.00.BHZ.SAC.bp',
#  'AV.PS4A..BHZ.SAC.bp',
#  'AU.KMBL..BHZ.SAC',
#  'AK.GLI..BHZ.SAC.bp',
#  'GE.SUMG..BHZ.SAC',
#  'AT.SDPT..BHZ.SAC',
#  'CH.FUORN..BHZ.SAC.bp',
#  'AU.RABL.00.BHZ.SAC',
#  'GE.UGM..BHZ.SAC.bp',
#  'G.CLF.00.BHZ.SAC',
#  'AC.PUK..HHZ.SAC',
#  'AK.SKN..BHZ.SAC.bp',
#  'CN.YUK6..HHZ.SAC',
#  'AV.PN7A..BHZ.SAC',
#  'IU.MIDW.00.BHZ.SAC',
#  'DK.ISOG..BHZ.SAC.bp',
#  'AV.AKSA..BHZ.SAC.bp',
#  'JP.JWT..BHZ.SAC.bp',
#  'IU.CTAO.00.BHZ.SAC.bp',
#  'CN.YKAW3..BHZ.SAC',
#  '8A.SOLI..BHZ.SAC',
#  'AV.KIMD..EHZ.SAC.bp',
#  'CH.SLE..BHZ.SAC.bp',
#  'AK.BAGL..BHZ.SAC.bp',
#  'DK.ILULI..BHZ.SAC',
#  'AK.FALS..BHZ.SAC.bp',
#  'AT.MENT..BHZ.SAC',
#  'AV.MCIR..BHZ.SAC',
#  'G.ECH.00.BHZ.SAC.bp',
#  'GE.EIL..BHZ.SAC.bp',
#  'saclist',
#  'AC.BCI..HHZ.SAC',
#  'AK.BARK..BHZ.SAC',
#  'IU.TARA.00.BHZ.SAC.bp',
#  'CN.CLRN..BHZ.SAC',
#  'IC.MDJ.00.BHZ.SAC',
#  'AK.ISLE..BHZ.SAC',
#  'G.CRZF.00.BHZ.SAC',
#  'G.SSB.00.BHZ.SAC',
#  'AK.PPD..BHZ.SAC.bp',
#  'AU.HTT..BHZ.SAC',
#  'IU.LSZ.00.BHZ.SAC.bp',
#  'CN.ILON..HHZ.SAC.bp',
#  'CA.CTRE..HHZ.SAC',
#  'AU.NFK..BHZ.SAC.bp',
#  'GE.TIRR..BHZ.SAC',
#  'AU.SDAN.00.BHZ.SAC.bp',
#  'AV.SSLS..BHZ.SAC.bp',
#  'AV.KCG..EHZ.SAC',
#  'II.MBAR.00.BHZ.SAC',
#  'AK.ANM..BHZ.SAC.bp',
#  'G.NOUC.00.BHZ.SAC',
#  'AV.GAKI..EHZ.SAC',
#  'AU.MCQ..BHZ.SAC',
#  'AK.PTPK..BHZ.SAC',
#  'AC.SRN..HHZ.SAC',
#  'DK.BSD..BHZ.SAC',
#  'AK.JIS..BHZ.SAC.bp',
#  '1E.MONT5..HHZ.SAC',
#  'II.AAK.00.BHZ.SAC',
#  'AK.WAT1..HHZ.SAC',
#  'AU.EIDS..BHZ.SAC',
#  'AK.KIAG..BHZ.SAC',
#  'BX.CKGRV..BHZ.SAC.bp',
#  'AU.XMIS..BHZ.SAC.bp',
#  'CA.CMAS..HHZ.SAC.bp',
#  'JP.JSU..BHZ.SAC.bp',
#  'CN.BMTB..HHZ.SAC',
#  'AK.CCB..BHZ.SAC',
#  'CN.NDB..HHZ.SAC.bp',
#  'AK.RAG..BHZ.SAC',
#  'AV.OPT..EHZ.SAC',
#  'CN.RES..BHZ.SAC',
#  'KO.ELL..BHZ.SAC.bp',
#  'AK.MCAR..BHZ.SAC.bp',
#  'AV.STLK..BHZ.SAC.bp',
#  'AF.SOE..BHZ.SAC',
#  'AV.ANNW..EHZ.SAC',
#  'CN.FRB..BHZ.SAC.bp',
#  'JP.JCJ..BHZ.SAC.bp',
#  'CN.YUK6..HHZ.SAC.bp',
#  'AU.XMIS..BHZ.SAC',
#  'AK.DHY..BHZ.SAC.bp',
#  'IU.GRFO..BHZ.SAC',
#  '1E.MONT3..HHZ.SAC.bp',
#  'DK.DY2G.10.BHZ.SAC',
#  'AK.FID..BHZ.SAC',
#  'CN.DLBC..BHZ.SAC.bp',
#  'AU.KNRA.00.BHZ.SAC.bp',
#  'AV.MTBL..BHZ.SAC.bp',
#  'AK.SPIA..BHZ.SAC',
#  'C8.GRIB..HHZ.SAC',
#  'II.ALE.00.BHZ.SAC.bp',
#  'AK.SII..BHZ.SAC',
#  'CA.CGAR..HHZ.SAC',
#  'KO.GURO..HHZ.SAC.bp',
#  'AK.TABL..BHZ.SAC.bp',
#  'AV.KOWE..EHZ.SAC.bp',
#  'II.RAYN.00.BHZ.SAC.bp',
#  'AF.TEBE..BHZ.SAC.bp',
#  'JP.JSG..BHZ.SAC.bp',
#  'G.NOUC.00.BHZ.SAC.bp',
#  'CH.MUGIO..BHZ.SAC',
#  'GE.DAG..BHZ.SAC',
#  'GE.VSU..BHZ.SAC',
#  'IU.CASY.00.BHZ.SAC',
#  'C8.BUTB..HHZ.SAC.bp',
#  'II.LVZ.00.BHZ.SAC.bp',
#  'CA.CFAR..HHZ.SAC.bp',
#  'KO.BZK..BHZ.SAC',
#  'IM.MK31..BHZ.SAC.bp',
#  'II.ALE.00.BHZ.SAC',
#  'DK.ICESG.00.BHZ.SAC.bp',
#  'AV.OKER..EHZ.SAC',
#  'AU.GIRL..BHZ.SAC.bp',
#  'CN.MOBC..HHZ.SAC',
#  '1E.MONT6..HHZ.SAC',
#  'HT.ALN..HHZ.SAC',
#  'AK.BMR..BHZ.SAC',
#  'IU.WAKE.00.BHZ.SAC',
#  'IU.GNI.00.BHZ.SAC',
#  'AK.CNP..BHZ.SAC',
#  'IU.CTAO.00.BHZ.SAC',
#  'AK.KLU..BHZ.SAC.bp',
#  'AV.ANPB..EHZ.SAC',
#  '7C.MM14..BHZ.SAC.bp',
#  'IU.KBL..BHZ.SAC',
#  'JP.JYT..BHZ.SAC.bp',
#  'AT.YKU2..BHZ.SAC.bp',
#  '8A.GAMM..BHZ.SAC.bp',
#  'AF.SKRH..BHZ.SAC.bp',
#  'AT.MENT..BHZ.SAC.bp',
#  'AK.CYK..BHZ.SAC.bp',
#  '1E.MONT2..HHZ.SAC.bp',
#  'G.ECH.00.BHZ.SAC',
#  'AV.MAPS..BHZ.SAC',
#  'AK.GAMB..BHZ.SAC.bp',
#  'IU.KONO.00.BHZ.SAC.bp',
#  'IU.ULN.00.BHZ.SAC.bp',
#  'IU.INCN.00.BHZ.SAC.bp',
#  'CA.CFAR..HHZ.SAC',
#  'CH.SLE..BHZ.SAC',
#  'CA.CCAS..HHZ.SAC',
#  'AV.ISLZ..BHZ.SAC',
#  'AU.WR2..BHZ.SAC',
#  'AV.PLK3..BHZ.SAC.bp',
#  'AK.CHN..BHZ.SAC.bp',
#  'AU.RIV..BHZ.SAC.bp',
#  'CN.CLRN..BHZ.SAC.bp',
#  'CA.CFON..HHZ.SAC',
#  'CN.WHY..HHZ.SAC',
#  'AK.GRIN..BHZ.SAC',
#  'AV.VNSS..EHZ.SAC',
#  '8A.KETS..BHZ.SAC',
#  'KO.BNN..BHZ.SAC',
#  '7C.MM14..BHZ.SAC',
#  'CH.SENIN..BHZ.SAC',
#  '8A.HOCH..BHZ.SAC.bp',
#  'AU.PSAD2.00.BHZ.SAC.bp',
#  'JP.JTU..BHZ.SAC.bp',
#  'AK.KNK..BHZ.SAC',
#  'AT.PMR..BHZ.SAC',
#  'HL.ARG..HHZ.SAC.bp',
#  'AK.BRSE..BHZ.SAC',
#  'AV.ADAG..EHZ.SAC',
#  '8A.OKAM..BHZ.SAC.bp',
#  'DK.SOEG.00.BHZ.SAC',
#  'II.OBN.00.BHZ.SAC',
#  'II.IBFO.00.BHZ.SAC',
#  'AC.LSK..HHZ.SAC',
#  'JP.JCJ..BHZ.SAC',
#  'AU.MORW..BHZ.SAC.bp',
#  'CN.BRWY..HHZ.SAC',
#  'CN.BNB..EHZ.SAC',
#  'AT.OHAK..BHZ.SAC.bp',
#  'CN.BNB..EHZ.SAC.bp',
#  'JP.JHS..BHZ.SAC',
#  'IM.EKR9..BHZ.SAC',
#  'II.KWJN.00.BHZ.SAC',
#  'AV.MREP..EHZ.SAC.bp',
#  'CN.POIN..HHZ.SAC',
#  'IU.KIEV.00.BHZ.SAC.bp',
#  'AT.CHGN..BHZ.SAC',
#  'II.MBAR.00.BHZ.SAC.bp',
#  'CN.BVCY..HHZ.SAC.bp',
#  'JP.JWT..BHZ.SAC',
#  '8A.MARI..BHZ.SAC.bp',
#  'AV.WESP..EHZ.SAC',
#  'AK.BCP..BHZ.SAC',
#  'AC.BCI..HHZ.SAC.bp',
#  'AU.STKA..BHZ.SAC',
#  'AK.BAGL..BHZ.SAC',
#  'AT.SIT..BHZ.SAC',
#  'AK.SSN..BHZ.SAC',
#  'JP.JHJ2..BHZ.SAC.bp',
#  'AK.FYU..BHZ.SAC.bp',
#  'IU.HNR.00.BHZ.SAC',
#  'JP.JKA..BHZ.SAC.bp',
#  'JP.JHS..BHZ.SAC.bp',
#  'IC.MDJ.00.BHZ.SAC.bp',
#  'AU.WRKA..BHZ.SAC.bp',
#  'AU.MOO..BHZ.SAC',
#  'IU.MAKZ.00.BHZ.SAC',
#  'HL.ITM..HHZ.SAC.bp',
#  'AV.MTBL..BHZ.SAC',
#  'G.AIS.00.BHZ.SAC',
#  '8A.HELM..BHZ.SAC',
#  'DK.NOR..BHZ.SAC.bp',
#  'KO.KARS..HHZ.SAC.bp',
#  'AK.SSN..BHZ.SAC.bp']

# %%
# Change the current directory
os.chdir(data_dir)

# Iteration Variable
j = 1

for sac in glob.glob("*.SAC.bp"):
    lst = sac.split(".")
    
    # lst[-3] represents the channel of the waveform
    if lst[-3] == "BHZ":
        # First Step --------------------------------
        st = obspy.read(sac)
        print(st)

        ### Visualize the seismic data
        fig = plt.figure(figsize=(12, 3))
        ax = fig.add_subplot()
        ax.plot(st[0].times("matplotlib"), st[0].data, color="black", label=st[0].stats.channel)
        ax.xaxis_date()
        ax.legend(loc ="upper left")

        fig.autofmt_xdate()
        plt.show()

        # Second step --------------------------------
        model = TauPyModel(model="iasp91")
        gcarc = st[0].stats.sac.gcarc
        evdp = st[0].stats.sac.evdp
        arrivals = model.get_travel_times(source_depth_in_km=evdp,
                                distance_in_degree=gcarc, phase_list=["ttp"])

        tp_iasp91 = arrivals[0].time
        print("Tp = {:.2f}s".format(tp_iasp91))

        # Third Step --------------------------------
        ### Predict P-wave arrival using STA/LTA method
        df = st[0].stats.delta
        # 0.5s short-term window; 3.0s long-term window
        cft = classic_sta_lta(st[0].data, int(0.5/df), int(60/df))   

        # Fourth Step --------------------------------
        ### Visualize the prediction results
        wlength = st[0].stats.sac.npts

        for s in range(0, int(st[0].stats.endtime - st[0].stats.starttime), wlength):
            t0 = st[0].stats.starttime + s
            t1 = t0 + wlength
            subst = st.slice(t0, t1)

        fig = plt.figure(figsize=(12,6))

        ax1 = fig.add_subplot(211)
        ax1.plot(subst[-1].times(), subst[-1].data / np.amax(abs(subst[-1].data)), 'k', label=subst[-1].stats.channel)
        ax1.axvline(x=tp_iasp91,color="green",linewidth=3,alpha=0.5,label="P-arrival: (IASP91)")
        ax1.set_ylabel('Normalised Amplitude')
        ax1.plot(subst[-1].times(), cft / np.amax(cft), label="STA/LTA", color="red",alpha=0.7)
        rect = patches.Rectangle((tp_iasp91-10, -1), 30, 1.6*1.0, color='gray',alpha=0.1)
        ax1.add_patch(rect)
        ax1.legend(loc="lower right")

        ax2 = fig.add_subplot(212)
        idxs1 = int((tp_iasp91-10)/st[0].stats.delta)
        idxs2 = int((tp_iasp91+20)/st[0].stats.delta)
        ax2.plot(subst[-1].times()[idxs1:idxs2], subst[-1].data[idxs1:idxs2] / np.amax(abs(subst[-1].data[idxs1:idxs2])), 'k', label=subst[-1].stats.channel)
        ax2.axvline(x=tp_iasp91,color="green",linewidth=3,alpha=0.5,label="P-arrival: (IASP91)")
        ax2.set_ylabel('Normalised Amplitude')
        ax2.plot(subst[-1].times()[idxs1:idxs2], cft[idxs1:idxs2] / np.amax(cft[idxs1:idxs2]), label="STA/LTA", color="red",alpha=0.7)
        rect = patches.Rectangle((tp_iasp91-10, -1), 30, 2.0*1.0, color='gray',alpha=0.1)
        ax2.add_patch(rect)
        ax2.legend(loc="lower right")

        plt.show()

        if j >= 20: break
        j += 1
# Out:
# 1 Trace(s) in Stream:
# AK.GRNC..BHZ | 2018-11-28T10:17:09.108400Z - 2018-11-28T11:17:09.058400Z | 20.0 Hz, 72000 samples
# Tp = 727.89s
# 1 Trace(s) in Stream:
# AK.BERG..BHZ | 2018-11-28T10:17:09.108400Z - 2018-11-28T11:17:09.058400Z | 20.0 Hz, 72000 samples
# Tp = 725.00s
# 1 Trace(s) in Stream:
# DK.SOEG.00.BHZ | 2018-11-28T10:17:09.100000Z - 2018-11-28T11:17:09.050000Z | 20.0 Hz, 72000 samples
# Tp = 712.70s
# 1 Trace(s) in Stream:
# AK.PWL..BHZ | 2018-11-28T10:17:09.108400Z - 2018-11-28T11:17:09.058400Z | 20.0 Hz, 72000 samples
# Tp = 713.37s
# 1 Trace(s) in Stream:
# BE.RCHB..BHZ | 2018-11-28T10:17:09.119538Z - 2018-11-28T11:17:09.069538Z | 20.0 Hz, 72000 samples
# Tp = 672.67s
# 1 Trace(s) in Stream:
# AV.RED..BHZ | 2018-11-28T10:17:09.100000Z - 2018-11-28T11:17:09.050000Z | 20.0 Hz, 72000 samples
# Tp = 704.30s
# 1 Trace(s) in Stream:
# II.ABPO.00.BHZ | 2018-11-28T10:17:09.119538Z - 2018-11-28T11:17:09.069538Z | 20.0 Hz, 72000 samples
# Tp = 647.24s
# 1 Trace(s) in Stream:
# II.AAK.00.BHZ | 2018-11-28T10:17:09.119539Z - 2018-11-28T11:17:09.069539Z | 20.0 Hz, 72000 samples
# Tp = 311.14s
# 1 Trace(s) in Stream:
# AV.ILS..BHZ | 2018-11-28T10:17:09.100000Z - 2018-11-28T11:17:09.050000Z | 20.0 Hz, 72000 samples
# Tp = 704.92s
# 1 Trace(s) in Stream:
# DK.BSD..BHZ | 2018-11-28T10:17:09.119400Z - 2018-11-28T11:17:09.069400Z | 20.0 Hz, 72000 samples
# Tp = 628.41s
# 1 Trace(s) in Stream:
# AK.RND..BHZ | 2018-11-28T10:17:09.108400Z - 2018-11-28T11:17:09.058400Z | 20.0 Hz, 72000 samples
# Tp = 704.21s
# 1 Trace(s) in Stream:
# AK.LOGN..BHZ | 2018-11-28T10:17:09.108400Z - 2018-11-28T11:17:09.058400Z | 20.0 Hz, 72000 samples
# Tp = 729.09s
# 1 Trace(s) in Stream:
# AK.WRH..BHZ | 2018-11-28T10:17:09.108400Z - 2018-11-28T11:17:09.058400Z | 20.0 Hz, 72000 samples
# Tp = 702.46s
# 1 Trace(s) in Stream:
# AT.MID..BHZ | 2018-11-28T10:17:09.100000Z - 2018-11-28T11:17:09.050000Z | 20.0 Hz, 72000 samples
# Tp = 722.41s
# 1 Trace(s) in Stream:
# JP.JEW..BHZ | 2018-11-28T10:17:09.100000Z - 2018-11-28T11:17:09.050000Z | 20.0 Hz, 72000 samples
# Tp = 445.42s
# /tmp/ipykernel_320019/2920484431.py:54: RuntimeWarning: invalid value encountered in true_divide
#   ax1.plot(subst[-1].times(), subst[-1].data / np.amax(abs(subst[-1].data)), 'k', label=subst[-1].stats.channel)
# /tmp/ipykernel_320019/2920484431.py:65: RuntimeWarning: invalid value encountered in true_divide
#   ax2.plot(subst[-1].times()[idxs1:idxs2], subst[-1].data[idxs1:idxs2] / np.amax(abs(subst[-1].data[idxs1:idxs2])), 'k', label=subst[-1].stats.channel)
# 1 Trace(s) in Stream:
# IU.PAB.00.BHZ | 2018-11-28T10:17:09.119539Z - 2018-11-28T11:17:09.069539Z | 20.0 Hz, 72000 samples
# Tp = 732.60s
# 1 Trace(s) in Stream:
# II.ARTI.00.BHZ | 2018-11-28T10:17:09.119538Z - 2018-11-28T11:17:09.069538Z | 20.0 Hz, 72000 samples
# Tp = 452.53s
# 1 Trace(s) in Stream:
# JP.JMM..BHZ | 2018-11-28T10:17:09.100000Z - 2018-11-28T11:17:09.050000Z | 20.0 Hz, 72000 samples
# Tp = 436.96s
# 1 Trace(s) in Stream:
# KO.GAZ..BHZ | 2018-11-28T10:17:09.100000Z - 2018-11-28T11:17:09.050000Z | 20.0 Hz, 72000 samples
# Tp = 537.29s
# 1 Trace(s) in Stream:
# 7C.MM27..BHZ | 2018-11-28T10:17:09.100000Z - 2018-11-28T11:17:09.050000Z | 20.0 Hz, 72000 samples
# Tp = 739.55s
